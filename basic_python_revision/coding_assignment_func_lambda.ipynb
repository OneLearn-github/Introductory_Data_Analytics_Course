# %% [markdown]
# <a href="https://colab.research.google.com/github/OneLearn-github/Introductory_Data_Analytics_Course/blob/main/basic_python_revision/coding_assignment_func_lambda.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# No 1 . Write a function that takes two arguments (feet and inches) and returns height in meters .

# %% [markdown]
# No 2 . Write a function in python to display the elements of list
# * once if it is a number For eg. if element is 34 just print 34
# * if it is a string print all the characters in the string as a list. For eg. if element is "STAR" print ['S','T','A','R']
#
# Example: <br>
# Sample Input : l1 = [34,55,"STAR", "ONE", 2, "TWO"] <br>
# Sample Output: <br>
# 34 <br>
# 55 <br>
# ['S','T', 'A', 'R'] <br>
# ['O','N', 'E'] <br>
# 2 <br>
# ['T', 'W', 'O']

# %% [markdown]
# HINT - Question 2

# %%
# you can .isdigit() function to check if a string is a number or not
# for eg.
print('123'.isdigit()) # print True as '123' is a number
print('abc'.isdigit()) #print False as 'abc is a string
# Out:
# True
# False

# %%
# .isdigit() only works on string it will not work with integers
print(1.isdigit()) # this will give error
# Out:
#   File "<ipython-input-2-fe4b8dd24765>", line 2
#     print(1.isdigit()) # this will give error
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# No 3 . Write a Python program to create a lambda function that adds 10 to a given number passed in as an argument, also create a lambda function that multiplies argument x with argument y and print the result

# %% [markdown]
# No 4. Write a Python program to find whether a given string starts with a given character using Lambda.
