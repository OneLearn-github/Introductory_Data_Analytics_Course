# %% [markdown]
# <a href="https://colab.research.google.com/github/OneLearn-github/Introductory_Data_Analytics_Course/blob/main/basic_python_revision/Advanced_Print_Formatting.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# 1. Write a function that takes two arguments (feet and inches) and returns height in meters .

# %% [markdown]
# 2. Write a function in python to display the elements of list
# * once if it is a number For eg. if element is 34 just print 34
# * if it is a string print all the characters in the string as a list. For eg. if element is "STAR" print ['S','T','A','R']
#
# Example: \
# Sample Input : l1 = [34,55,"STAR", "ONE", 2, "TWO"] \
# Sample Output: \
# 34 \
# 55 \
# ['S','T', 'A', 'R'] \
# ['O','N', 'E'] \
# 2 \
# ['T', 'W', 'O']

# %% [markdown]
# 3. Write a Python program to create a lambda function that adds 10 to a given number passed in as an argument, also create a lambda function that multiplies argument x with argument y and print the result

# %% [markdown]
# 4. Write a Python program to find whether a given string starts with a given character using Lambda.
