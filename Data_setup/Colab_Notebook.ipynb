# %% [markdown]
# <a href="https://colab.research.google.com/drive/1u9zzv2jqqmcG8e4kKll2Ah_dUDoco9G-?usp=sharing">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Colab Notebooks

# %% [markdown]
# Before starting to work with any lesson file or assignment in this course you need to <br>
# * Install Colaboratory on google drive (you can install it either directly from goolge workspace marketplace or while opening any jupyter notebook it will ask you to install colaboratory)
# * You can create a colab notebook by clicking on 'New' button and going to 'More' option from the dropdown.
# * This will open a new colab notebook with name 'Untitled.ipynb'.

# %% [markdown]
# You can even load any data saved on your drive in colab notebooks and use it in codes written in colab.

# %% [markdown]
# ## Understanding how colab notebooks work

# %% [markdown]
# Before working with tutorial and dataset, we need to understand how colab notebooks work

# %% [markdown]
# In essence a colab notebook is like your own computer hosted on cloud.
#
# So it has its own RAM, memory and computer folder structure.
#
# You can look at RAM usage by clicking on following red circle in image below.

# %% [markdown]
# ![RAM_on_colab1.png](https://drive.google.com/uc?export=view&id=1a6yVDkT0akqfUeCIQXoA_w3czbGuV0k9)

# %% [markdown]
# This will look like as shown below

# %% [markdown]
# ![RAM_on_colab_2.png](https://drive.google.com/uc?export=view&id=1IAX81EQHm-FR7PblCmkWiuvpe69HAw1M)

# %% [markdown]
# In the above picture we can also see the disk structure.
#
# But to see exactly how much disk space you have you can click on following red circle in the image below

# %% [markdown]
# ![disk_on_colab1.png](https://drive.google.com/uc?export=view&id=194HFh2LY9NRSmTFqcmSyPVDxSxqbp-_L)

# %% [markdown]
# Once you click on above button, you will observe the disk below and the current folder of the colab computer

# %% [markdown]
# ![disk_currentdir_upload.png](https://drive.google.com/uc?export=view&id=1M1Mm_BvXs_yg51fyI2UFVuVtRt8RR3VK)

# %% [markdown]
# In the above image:<br>
# * the below red circle shows the available disk space
# * the blue circle shows the folder in current directory
# * the green circle shows the button we can use to upload our files to colab and use it.
#
#
# We can actually see what is the current directory name using the following command

# %%
# %pwd
# Out:
# '/content'

# %% [markdown]
# If you want to look into the actual folder structure you can click on 'up arrow' just above sample_data folder. (don't confuse it with the green circled up arrow which is for uploading files from your own computer to this colab)
#
# It will open the following directory structure, where you can observe the current directory name as content marked inside red circle

# %% [markdown]
# ![colab_dir_structure.png](https://drive.google.com/uc?export=view&id=1wSN9PnjDJza7vBzfXG5S3uqCC-KlBSw4)

# %% [markdown]
# You can even look into all the files in a given directory in colab using the following command

# %%
# %ls
# Out:
# sample_data/
