# %% [markdown]
# <a href="https://colab.research.google.com/drive/1qmKr-l65u40ZG7jwQ3q5S7dRBYkcWos9?usp=sharing">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# This notebook is about how to use the data that we will need for this project in colab.

# %% [markdown]
# # Downloading the dataset for this project

# %% [markdown]
# We will be using two datasets for completing this project
# * IMDB movies dataset
# * Rotten tomatoes dataset
#
# **Downloading the dataset**<br>
# You can download IMDB dataset from kaggle using the following link - https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset<br>
# You can download Rotten tomatoes dataset from kaggle using the following link - https://www.kaggle.com/stefanoleone992/rotten-tomatoes-movies-and-critic-reviews-dataset
#
# For downloading the dataset, you may need to register on kaggle.
#
# You will get a zipped file once you download the dataset.
#
#
# **Access the data files for tutorial**<br>
# *1st way - running the code on local computer*<br>
# Unzip the files and save the data folder in appropriate folder in your computer from where you can access it, if you want to run the tutorial files on computer.
#
# *2nd way - running the code on colaboratory*<br>
# If you want to run the tutorial files on colab, it would be better to save these data folder on google drive.
#
# We recommend to work with tutorials using the 2nd way as it is easier to work with.

# %% [markdown]
# # Mounting the data folder in google drive to colaboratory

# %% [markdown]
# If you want to utilise the data folder using colaboratory, you need to save the files on google drive.
#
# Below instructions shows how to load the google drive file in colaboratory.
#
# Before starting to work with colab in google drive you need to <br>
# Install Colaboratory on drive (you can install it either directly from goolge workspace marketplace or while opening any jupyter notebook it will ask you to install colaboratory)
#
# Important instructions from below will be available in all the notebooks where you need to work with data in colab.

# %% [markdown]
# ## Mounting Data from google drive in colab

# %% [markdown]
# This step is about getting all the data saved in your drive accessible in colab notebook. This is called mounting google drive in colab.
#
# You can click on the button inside the red circle in the image below

# %% [markdown]
# ![mount_drive_1.png](https://drive.google.com/uc?export=view&id=1e26y6TlVVEEg3Y7goQZz6-SKm8pzdAFR)

# %% [markdown]
# Once you click over that button following permission will be asked in order to mount the drive, click on connect to drive button in the below image

# %% [markdown]
# ![mount_drive_2.png](https://drive.google.com/uc?export=view&id=1dk6B7hb0xEh9Ex4dj0z4OouLG5Dj-fEz)

# %% [markdown]
# You can see the drive folder coming up above sample_data folder.

# %% [markdown]
# ![mount_drive_3.png](https://drive.google.com/uc?export=view&id=1yQ1zrrzXU3LC09YOY59ZWUOHw7LNgQVn)

# %% [markdown]
# We can access the drive folder and files inside using the following command

# %%
# going inside the drive folder
# %cd drive
# Out:
# /content/drive

# %%
# listing files inside drive folder
# %ls
# Out:
# MyDrive/  Othercomputers/  Shareddrives/

# %% [markdown]
# MyDrive  - It is your google drive folder<br>
# Othercomputers - it is the folder on your computer that you have synced with google drive<br>
# Shareddrives - It is the folder which materials shared with you
#
# Now for accessing the data you need to know the location of the dataset.
#
# In this case the data is saved in following folder (In your case you may have saved it in another folder, use that folder path for below insturctions)
#
# /content/drive/Othercomputers/My MacBook Pro/Data/IMDB_rotten_tomato_dataset/
#
# You can see the files inside this folder using the following command

# %%
# %ls /content/drive/Othercomputers/My\ MacBook\ Pro/Data/IMDB_rotten_tomato_dataset/
# Out:
# IMDB/  rotten_tomatoes/

# %% [markdown]
# You can look into IMDB and rotten_tomatoes data folder as shown below

# %%
# %ls /content/drive/Othercomputers/My\ MacBook\ Pro/Data/IMDB_rotten_tomato_dataset/IMDB
# Out:
# 'IMDb movies.csv'  'IMDb ratings.csv'
# 'IMDb names.csv'   'IMDb title_principals.csv'

# %%
# %ls /content/drive/Othercomputers/My\ MacBook\ Pro/Data/IMDB_rotten_tomato_dataset/rotten_tomatoes
# Out:
# rotten_tomatoes_critic_reviews.csv  rotten_tomatoes_movies.csv

# %% [markdown]
# You can directly use this path name if you want to access the files in tutorials.

# %% [markdown]
# # Sym linking data folder in '/content' folder - Simplifying data access

# %% [markdown]
# To simplify accessing the files without writing this big path name, you can use the following command which creates a symbolic link of your Data folder to /content folder

# %%
# sym linked the original data folder to new location at /content/Data
# !ln -s "/content/drive/Othercomputers/My MacBook Pro/Data" "/content/Data"

# %% [markdown]
# Once you execute above command Data folder will appear above drive folder in /content folder

# %% [markdown]
# ![symlink.png](https://drive.google.com/uc?export=view&id=1LQyLTj1UT-T6hlqB7t6Chf30Nta07Ci2)

# %% [markdown]
# You can use the following command to observe all the Data files inside /content

# %%
# %ls /content/Data/IMDB_rotten_tomato_dataset/
# Out:
# IMDB/  rotten_tomatoes/

# %% [markdown]
# While accessing the data you can use this path name

# %% [markdown]
# # Data Setup Instructions

# %% [markdown]
# These are the instructions for mounting the data from google drive to colab and accessing it in the colab.

# %% [markdown]
# STEP 1 - After opening the tutorial in  your colab, go to folder button and click on mount google drive

# %% [markdown]
# STEP 2 - drive folder will be mounted in the current directory of /content, you can access it as below

# %%
# print current directory
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# drive/  sample_data/

# %% [markdown]
# STEP 3 - Find your data folder where you saved the data and sym link it to /content folder so as to simplify data access

# %% [markdown]
# In the current case the Data folder is located at this path in google drive (Use your own data path in your case)
#
# /content/drive/Othercomputers/My MacBook Pro/Data/
#
# We can sym link it to /content folder using the following command

# %%
# sym linked the original data folder to new location at /content/Data
# !ln -s "/content/drive/Othercomputers/My MacBook Pro/Data" "/content/Data"

# %% [markdown]
# Now we can access the data from this folder by simply giving the file path name after /Data
