# %% [markdown]
# <a href="https://colab.research.google.com/github/OneLearn-github/Introductory_Data_Analytics_Course/blob/main/basic_python_revision/Data_Type.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Library Installation and Import

# %% [markdown]
# If you do not have pandas library installed, you can start with installation with below command

# %%
# !pip install pandas
# Out:
# ...
# WARNING: Error parsing requirements for ipython: [Errno 2] No such file or directory: '/Users/aruneshn/anaconda3/lib/python3.6/site-packages/ipython-7.16.1.dist-info/METADATA'

# %% [markdown]
# After installation the easiest way to import pandas library into your jupyter notebook is

# %%
# import pandas with alias pd
import pandas as pd

# check pandas version
print(pd.__version__)
# Out:
# 1.1.5
