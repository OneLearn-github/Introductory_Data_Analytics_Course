# %% [markdown]
# <a href="https://colab.research.google.com/drive/1z21MXq9d3zY17fTfLhfuflxkysvU2eF1?usp=sharing">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# This tutorial needs data so if you are working on colab follow the below data setup instruction

# %% [markdown]
# # Data Setup Instructions

# %% [markdown]
# These are the instructions for mounting the data from google drive to colab and accessing it in the colab.

# %% [markdown]
# STEP 1 - After opening the tutorial in  your colab, go to folder button and click on mount google drive

# %% [markdown]
# STEP 2 - drive folder will be mounted in the current directory of /content, you can access it as below

# %%
# print current directory
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# drive/  sample_data/

# %% [markdown]
# STEP 3 - Find your data folder where you saved the data and sym link it to /content folder so as to simplify data access

# %% [markdown]
# In the current case the Data folder is located at this path in google drive (Use your own data path in your case)
#
# /content/drive/Othercomputers/My MacBook Pro/Data/
#
# We can sym link it to /content folder using the following command

# %%
# sym linked the original data folder to new location at /content
# !ln -s "/content/drive/Othercomputers/My MacBook Pro/Data" "/content"

# %% [markdown]
# Now we can access the data from this folder by simply giving the file path name after /Data

# %% [markdown]
# # **Question 1**

# %% [markdown]
# Load the dataset movies_cleaned.csv (this is the cleaned IMDB movies dataset that we created in pandas data cleaning lessons) in the dataframe movies_cleaned.
#
# Also load the dataset movies_income_cleaned.csv (this is the IMDB movies dataset with cleaned worldwide_gross_income column that we had created in Pandas data cleaning lessons) in the dataframe movies_cleaned_income.

# %% [markdown]
# # **Question 2**

# %% [markdown]
# Plot scatter plot of worldwide_gross_income column with imdb_score from the dataframe movies_cleaned_income. Also add appropriate title to this graph and hover_data of year and movie title to each point of this scatter plot.

# %% [markdown]
# # **Question 3**

# %% [markdown]
# Using movies_cleaned dataframe, Create the box plot of imdb_score for the 'Action' genre movies.
#
# Using movies_cleaned_income dataframe, Create the box plot of worldwide_gross_income for the 'Action' genre movies.

# %% [markdown]
# # **Question 4**

# %% [markdown]
# Create the bar plot of average worldwide gross income for each genre.
#
# Create the bar plot of average worldwide gross income for movies released in each country.

# %% [markdown]
# # **Question 5**

# %% [markdown]
# Using movies_cleaned dataframe, draw the box plot of imdb_score for all the genres in one graph.
