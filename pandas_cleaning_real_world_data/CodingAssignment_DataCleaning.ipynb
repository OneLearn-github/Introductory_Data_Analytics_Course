# %% [markdown]
# <a href="https://colab.research.google.com/drive/1HgunPsdXHUP3ruijcq5vkCtKnxgwblrY?usp=sharing">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# This assignment needs data so if you working on colab follow the below data setup instruction

# %% [markdown]
# # Data Setup Instructions

# %% [markdown]
# These are the instructions for mounting the data from google drive to colab and accessing it in the colab.

# %% [markdown]
# STEP 1 - After opening the tutorial in  your colab, go to folder button and click on mount google drive

# %% [markdown]
# STEP 2 - drive folder will be mounted in the current directory of /content, you can access it as below

# %%
# print current directory
# %pwd

# %%
# %ls

# %% [markdown]
# STEP 3 - Find your data folder where you saved the data and sym link it to /content folder so as to simplify data access

# %% [markdown]
# In the current case the Data folder is located at this path in google drive (Use your own data path in your case)
#
# /content/drive/Othercomputers/My MacBook Pro/Data/
#
# We can sym link it to /content folder using the following command

# %%
# sym linked the original data folder to new location at /content
# !ln -s "/content/drive/Othercomputers/My MacBook Pro/Data" "/content"

# %% [markdown]
# Now we can access the data from this folder by simply giving the file path name after /Data

# %% [markdown]
# # **Question 1**

# %% [markdown]
# Read the IMDB_ratings_saved.csv in df_rating. In df_ratings drop all columns except:
# * 'imdb_title_id' - This column identifies the movie with the help of IMDB id.
# * 'weighted_average_vote' - This column is basically IMDB ratings
# * 'males_allages_avg_vote' - This column is IMDB rating based on just male voter rating
# * 'females_allages_votes' - This column is IMDB rating based on just female voter rating

# %% [markdown]
# # **Question 2**

# %% [markdown]
# Rename the columns of df_ratings as shown below:<br>
# * 'imdb_title_id' - don't change
# * 'weighted_average_vote' - imdb_score_overall
# * 'males_allages_avg_vote' - imdb_score_male
# * 'females_allages_avg_vote' - imdb_score_female

# %% [markdown]
# # **Question 3**

# %% [markdown]
# Create a new column in df_ratings dataframe called gender_preference based on male and female imdb score column. This column  should tell which gender prefers a given movie, if prefernece is same then column column should tell both genders prefer the movie.

# %% [markdown]
# # **Question 4**

# %% [markdown]
# Read movies_cleaned_lesson2.csv file from the folder cleaned_files that you have saved during data cleaning lesson.
#
# Read the above file in df_movies dataframe.
#
# Clean the budget column from missing value and convert it into numeric data type column. (take only dollar based budget value).
#
# Save the budget column cleaned cleaned dataframe in df_clean_bud dataframe.

# %% [markdown]
# # **Question 5**

# %% [markdown]
# In the dataframe df_clean_bud.
#
# Clean the worldwide_gross_income column from missing value and convert it into numeric data type column. (take only dollar based gross income value).
#
# The final cleaned dataframe will have both the budget and gross_income_column cleaned. Save this in the dataframe df_clean_budinc.

# %% [markdown]
# # **Question 6**

# %% [markdown]
# Create a new column in the dataframe df_clean_budinc called movie_success.
#
# Follow this logic to set the value of column movie_sucess - If budget>income then movie failed and vice versa.

# %% [markdown]
# # **Question 7**

# %% [markdown]
# Save the following dataframe in following files:(save these files in appropriate folder as you will use them for further lessons)<br>
# df_clean_budinc - movies_budinc_cleaned.csv<br>
# df_ratings - movies_ratings_cleaned.csv
