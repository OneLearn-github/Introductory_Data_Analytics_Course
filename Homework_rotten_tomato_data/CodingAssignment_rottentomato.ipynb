# %% [markdown]
# <a href="https://colab.research.google.com/drive/1aV0v8IzNTepA8nI4evS6UhdikhEYaIiJ?usp=sharing">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# This assignment needs data so if you working on colab follow the below data setup instruction

# %% [markdown]
# # Data Setup Instructions

# %% [markdown]
# These are the instructions for mounting the data from google drive to colab and accessing it in the colab.

# %% [markdown]
# STEP 1 - After opening the tutorial in  your colab, go to folder button and click on mount google drive

# %% [markdown]
# STEP 2 - drive folder will be mounted in the current directory of /content, you can access it as below

# %%
# print current directory
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# drive/  sample_data/

# %% [markdown]
# STEP 3 - Find your data folder where you saved the data and sym link it to /content folder so as to simplify data access

# %% [markdown]
# In the current case the Data folder is located at this path in google drive (Use your own data path in your case)
#
# /content/drive/Othercomputers/My MacBook Pro/Data/
#
# We can sym link it to /content folder using the following command

# %%
# sym linked the original data folder to new location at /content
# !ln -s "/content/drive/Othercomputers/My MacBook Pro/Data" "/content"

# %% [markdown]
# Now we can access the data from this folder by simply giving the file path name after /Data

# %% [markdown]
# # **Questions**

# %% [markdown]
# 1. Read the rotten tomato file which contains movies data. Also read movies_cleaned.csv file for the movies data from IMDB.
#
# 2. Retain the following columns in rotten tomatoes dataframe - 'movie_title','original_release_date','tomatometer_rating'.
#
# 3. Clean the rows of rotten tomatoes dataframe with missing original_release_date column values.
#
# 4. Create a year column from original_release_date column of rotten tomatoes dataframe. Drop the original_release_date column. Convert the year column datatype to int.
#
# 5. Guess which columns can be used from rotten tomato and IMDB dataset for joining the two datasets in one place.
#
# 6. Join IMDB cleaned data(movies_cleaned.csv file that you created in data cleaning chapter) and the above rotten tomato dataframe based on movie_title. (you need to have same column name while joining so ensure that)
# - Joining on movie_title column from rotten tomato and IMDB, the join will not be completely correct. Can you tell the reason why it is so?
# HINT -  check the movie with title 'Cleopatra' in IMDB dataset, rotten tomato dataset and combined dataset.
#
# 7. You need to use one more column other than movie title for joining the two dataframe of IMDB and rotten tomato properly. Can you guess which column can be used other than title column for joining. Use that column to do the final joining between the two dataframes imdb and rotten tomatoes.
#
# 8. drop following columns in the joined dataframe
# 'imdb_title_id','date_published','votes','budget','usa_gross_income','metascore','movie_age'
#
# 9. Clean the worldwide gross income column in the joined dataframe. Remove rows where worldwide gross income is missing, also remove '$' sign from gross income value and change the datatype of column to number.
# Finally divide all the values of worldwide gross income column with 1000000 so that each value is in millions
#
# 10. Also scale up imdb_score column by multiplying each value with 10. This will help in easy comparsion of tomatometer rating with IMDB score as tomatometer rating is in range 1 to 100.
#
# 11. Save the cleaned and combined dataframe in the file combined_data.csv. This will be the final dataframe which we will use for final project analysis.
