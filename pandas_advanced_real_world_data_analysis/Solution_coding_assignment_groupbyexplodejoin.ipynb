# %% [markdown]
# <a href="https://colab.research.google.com/drive/1MzTdhMTnWSu8Lzb-X8gk8G8WrPWu5ADM?usp=sharing">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# This assignment needs data so if you working on colab follow the below data setup instruction

# %% [markdown]
# # Data Setup Instructions

# %% [markdown]
# These are the instructions for mounting the data from google drive to colab and accessing it in the colab.

# %% [markdown]
# STEP 1 - After opening the tutorial in  your colab, go to folder button and click on mount google drive

# %% [markdown]
# STEP 2 - drive folder will be mounted in the current directory of /content, you can access it as below

# %%
# print current directory
# %pwd
# Out:
# '/content'

# %%
# %ls
# Out:
# drive/  sample_data/

# %% [markdown]
# STEP 3 - Find your data folder where you saved the data and sym link it to /content folder so as to simplify data access

# %% [markdown]
# In the current case the Data folder is located at this path in google drive (Use your own data path in your case)
#
# /content/drive/Othercomputers/My MacBook Pro/Data/
#
# We can sym link it to /content folder using the following command

# %%
# sym linked the original data folder to new location at /content
# !ln -s "/content/drive/Othercomputers/My MacBook Pro/Data" "/content"

# %% [markdown]
# Now we can access the data from this folder by simply giving the file path name after /Data

# %% [markdown]
# # **Question 1**

# %% [markdown]
# Load the csv file "movies_cleaned.csv".
#
# Find the genre with highest number of movies with IMDB ratings more than 9.

# %% [markdown]
# # **Question 2**

# %% [markdown]
# Load the csv file movies_budinc_cleaned.csv that you created in pandas data cleaning assignment in the dataframe df_cleaned_budinc.
#
# Load the csv file movies_ratings_cleaned.csv that you created in pandas data cleaning assignment in the dataframe df_cleaned_ratings.

# %% [markdown]
# # **Question 3**

# %% [markdown]
# Join the dataframes df_cleaned_budinc and df_cleaned_ratings on the column 'imdb_title_id'.

# %% [markdown]
# # **Question 4**

# %% [markdown]
# Find the mean female and male ratings of all the successful and unsuccessful movies based on the joined dataframe that you created above. (Use movies_success column from df_cleaned_budinc column for finding successful and unsuccessful movies - this column would have come up in joined dataframe as well).

# %% [markdown]
# # **Question 5**

# %% [markdown]
# Based on the dataframe df_cleaned_budinc, for each year find the maximum worldwide_gross_income value and the maximum budget value.

# %% [markdown]
# # **Question 6**

# %% [markdown]
# Find the average movie duration value for
# * movies released before and after 1990 (use df_cleaned_movies)
# * successful and unsuccessful movies (use df_cleaned_budinc)

# %% [markdown]
# # **Question 7**

# %% [markdown]
# Using the joined dataframe, find the most preferred genre for males and females.
#
# Also find the number of movies for each genre with ratings more than 8 from both males and females.
